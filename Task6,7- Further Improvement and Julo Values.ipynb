# %% [markdown]
# Scorecard Development Involves few but very crucial steps. Excersise covered only few of them
#
# Would suggest further improvement involves Business and Product Understanding alongside technical development
#
# ### Scorecard Development Plan ####
# * Analyze & Breakdown Product Portfolio to learn about possible trends
#    * **Business Goal:** the main goal is to build a robust credit scoring model that aids automation and optimization of customer on-boarding process from an application point of through-the-cycle strategy. The solution aims to meet the following requirements:
#      * Reliability
#      * Transparency
#      * Profit and Growth-driven
#    * **Project Goal:** The credit risk application scorecard would assist in evaluating probability of customer defaults. This end-to-end advanced credit risk analytics would focuses on:
#      * Meeting business goals
#      * Optimization of the overall customer acquisition funnel based on the association between the scoring model within GDS (and/or Provenir).
#      * Build a holistic customer risk profile for Lite-loan customers
#
#   ##### PART 1 Data Preparation and Exporatory Data Analysis
#
#   * Remove operational risk ids
#   * Data Audit: Verifying data quality
#   * Distribution of Through-the-door Applications
#      * Understand take-up rates against total apps - the higher the take-up the higher the revenue generated
#   * Trend of Application Loan ticket size distribution
#   * Distribution of Through-the-door Loan Applications per Channel
#   * Trend of Total Application population vs Acceptance rates vs decline rates month-on-month
#   * Trend of top reasons for lite loan applications rejects
#   * Trend of Disbursed Loan ticket size distribution month-on-month
#
#   ##### Part 2 Behavioral Analysis
#
#   * Analysis of early settlement events across the overall disbursed samples
#   * Exclusion of early **settlement flag 1** from the disbursed population
#   * Understanding Maximum delinquency event trends for Lite loans:
#     * Default rates analysis
#     * Cure rates analysis
#   * Define Target definition
#     * Good/Bad flag
#
#  ##### PART 3 Feature Engineering
#   * Cross variables
#   * Ratios
#
#   ##### PART 4 Data Preparation
#   * Characteristics Analysis Report
#     * Fine Classing
#     * Coarse Classing
#     * Information value
#     * WoE transformations
#     * Univariate Analysis/ Feature Selection
#
#  ##### PART 5 Scorecard Development
#   * Modelling Phase
#    * Variable Selection
#   * Model Correlation Analysis
#   * Model evaluation:
#      * Hold Out Sample Validation
#      * Out-of-time validation
#      * Recent sample validation
#      * Score validation
#      * Score calibration
#
# ##### PART 6 Cut off strategy
#    * Cut-off Analysis
#    * swap-set analysis
#    * Profitability Analysis
#       * Cost Analysis:
#         * Dependecies (Unit Economics):
#           - Cost of customer acquisition
#           - Marketing costs
#           - overheads & variable cost
#    * Probability of defaults Distribution (PDs)

# %% [markdown]
# ## Assignment 7
# At JULO, we have 6 values that we follow, that are following our two core values:
#
# ![6 Core Values](julo_values.png)
#
# **A. Please choose three Core Values from the 6 values above that you think is your strength, share us one specific example where you showed it**
#
# ***1- We are Responsible***
#
# As a DS Manager, its my job to understand product and business end to end because what we do is/will create direct impact on Portfolio.
# Thats y it is very important to understand business at first whether its Portfolio, Sales, Marketing or Collection. Once you able to understand the business flow it would be easier for you to ask the RIGHT QUESTIONS at the time of Project Understanding with Stakeholders.
#
# As the person guiding Data Science team, I genuinely care about more than just numbers and outcomes. Our company's mission means a lot to me, but so does respecting and valuing the diverse world we operate in. This means we're not just about complying with the laws; it's also about truly understanding and cherishing the cultures, beliefs, and values of the people we serve. I believe in creating a space where everyone feels seen and respected, where discrimination has no place. It's about listening, caring, and considering the needs and feelings of others in everything we do. We're here to make a positive impact, one that's felt on a truly human level.
#
# As an specifc exmaple, currently my team is composed of various demographics, people of differnt culture, different religion join and currently delivering value under my wings.
#
#
# ***2- We are Effective Team Players***
#
#
# A Good leader always would be a Good Listener. As a Manager or Lead you have to listen to your team members and understand their pain point. An Effective team would be which always aligned with the company goals and mission, thrive to attain milestones but at the same time do not get feel burn out.
#
# I always encourage my team to stay transperent and be open to communicate anything with me. Effective team players are the heartbeat of a collaborative and positive environment, where success is a shared journey, not just an individual accomplishment. They bring to the table not only their skills but also an unwavering commitment to work together, understand each other's strengths, and cover for weaknesses. These individuals thrive on mutual respect and open communication, always ready to listen, share ideas, and provide constructive feedback. They celebrate victories together and view challenges as opportunities to grow stronger as a unit. Holding each other accountable, they ensure that every member of the team is moving in the same direction, driven by a common purpose. In essence, effective team players are those who recognize that true success comes from the collective effort, trust, and accountability shared amongst each other.
#
# As an specific exmaple, I tend to have 1:1 session fortnightly with each of my team member where i just listen or discuss about the painpoint or how i can manage that employee more effectively.
#
# ***2- We Work Hard***
#
# That says alot when your team is performing efficeintly and capable to adapt with unique timelines.
#
# From my prespective, it goes from both ways, if Company appreciates its employee of delivering a value consistently and rewards him/her with benefits. It motivates employee to deliver more and more.
#
# As a Manager, We work hard, not just to meet expectations, but to surpass them. Our focus is on being productive and consistently delivering value to our business, always looking for ways to raise the bar. Every project, every task is an opportunity for team to contribute meaningfully, pushing the boundaries of what's possible. We're committed to continuous learning, always seeking to improve our work and ourselves.
#
# As an specifc exmaple, we tend to manage our project and goals in Agile manner. timelines aligned with stakeholders and when the Goal is defined for the sprint , employee can get relax if he achieve goal before sprint ends. In terms of learning, its a KPI of my each team member to learn a new set to tool every quarter and present it to rest of the team.

# %% [markdown]
# **B. Please choose three Core Values from the 6 values above that you think is your weakness, share us one specific example where you showed it**
#
# ***1- We are Committed to Excellence***
#
# Striving towards excellence is good but sometimes it delays the entire process and delivery. In Corporate culture, you need to be move fast towards delivery start with POC and then present a clear recalibration plan of your models.
#
# For instance, when we introduced the Insta Loan product in May, my team was tasked with delivering a scorecard at the time of launch. Instead of waiting for actual customer data to accumulate, we initially utilized proxy data to develop the scorecard. This approach allowed us to meet our launch deadlines efficiently. Then, after two months, once we had gathered a sufficient sample size of customer data, we revisited and refined our model. This strategy ensured that we could provide immediate value while also adapting and improving our model with more precise data over time.
#
# ***1- We are Critical***
#
# Thinking about our company's value of being critical, pushing each other to think deeper, and being thorough in how we evaluate things, I see an area where I can grow. Sometimes, I might hold back a bit too much when it comes to sharing my own critiques or questions.
#
# I really believe in the importance of diving deep and challenging ideas because it's how we get to the best outcomes. But, I admit, there are moments when I worry about stepping on toes or how my input might be taken, especially meeting with CCO or CEOs. I'm actively working on this by reminding myself that our team culture isn't just okay with asking tough questions—it actually welcomes it. I'm learning to trust my own insights more and to remember that voicing them is part of how we all grow together.

# %% [markdown]
# **C. Please order the 6 Core Values based on your priority if you work at JULO and why**
#
# 1. We are Responsible
# 2. We are Team Player
# 3. We Work Hard
# 4. We Strive for Transperency and Openness.
# 5. We are Critical
# 6. We are commited towards Excellence
#
# Everything is connected and thats the secret ingredient to lead a proper team in a good and non-toxic organization.
